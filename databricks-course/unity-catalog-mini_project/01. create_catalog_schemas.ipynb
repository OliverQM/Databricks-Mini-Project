-- %% [markdown]
-- # 1. CREAR CATALOG Y SCHEMAS

-- %%
CREATE CATALOG IF NOT EXISTS telco_dev;

-- %%
USE CATALOG telco_dev;

-- %%
CREATE SCHEMA IF NOT EXISTS bronce;

-- %%
CREATE SCHEMA IF NOT EXISTS silver;

-- %%
CREATE SCHEMA IF NOT EXISTS gold;
